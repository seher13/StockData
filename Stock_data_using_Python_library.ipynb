# %% [markdown]
# <a href="https://colab.research.google.com/github/seher13/StockData/blob/Test-branch/Stock_data_using_Python_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install yfinance==0.1.67
# Out:
# ...
#      |████████████████████████████████| 6.4 MB 10.6 MB/s
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf

# %%
apple = yf.Ticker('AAPL')

# %%
apple_info = apple.info

# %%
apple_info['country']
# Out:
# 'United States'

# %%
apple_share_price_data = apple.history(period='max')

# %%
apple_share_price_data
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 1980-12-12    0.100453    0.100890  ...        0.0           0.0
# 1980-12-15    0.095649    0.095649  ...        0.0           0.0
# 1980-12-16    0.088661    0.088661  ...        0.0           0.0
# 1980-12-17    0.090408    0.090845  ...        0.0           0.0
# 1980-12-18    0.093029    0.093466  ...        0.0           0.0
# ...                ...         ...  ...        ...           ...
# 2022-01-20  166.979996  169.679993  ...        0.0           0.0
# 2022-01-21  164.419998  166.330002  ...        0.0           0.0
# 2022-01-24  160.020004  162.300003  ...        0.0           0.0
# 2022-01-25  158.979996  162.759995  ...        0.0           0.0
# 2022-01-26  163.500000  164.389404  ...        0.0           0.0
#
# [10369 rows x 7 columns]

# %%
apple_share_price_data['Date_column'] = apple_share_price_data.index

# %%
apple_share_price_data
# Out:
#                   Open        High  ...  Stock Splits  Date_column
# Date                                ...
# 1980-12-12    0.100453    0.100890  ...           0.0   1980-12-12
# 1980-12-15    0.095649    0.095649  ...           0.0   1980-12-15
# 1980-12-16    0.088661    0.088661  ...           0.0   1980-12-16
# 1980-12-17    0.090408    0.090845  ...           0.0   1980-12-17
# 1980-12-18    0.093029    0.093466  ...           0.0   1980-12-18
# ...                ...         ...  ...           ...          ...
# 2022-01-20  166.979996  169.679993  ...           0.0   2022-01-20
# 2022-01-21  164.419998  166.330002  ...           0.0   2022-01-21
# 2022-01-24  160.020004  162.300003  ...           0.0   2022-01-24
# 2022-01-25  158.979996  162.759995  ...           0.0   2022-01-25
# 2022-01-26  163.500000  164.389404  ...           0.0   2022-01-26
#
# [10369 rows x 8 columns]

# %%
apple_share_price_data.reset_index(inplace=True)

# %%
apple_share_price_data
# Out:
#             Date        Open        High  ...  Dividends  Stock Splits  Date_column
# 0     1980-12-12    0.100453    0.100890  ...        0.0           0.0   1980-12-12
# 1     1980-12-15    0.095649    0.095649  ...        0.0           0.0   1980-12-15
# 2     1980-12-16    0.088661    0.088661  ...        0.0           0.0   1980-12-16
# 3     1980-12-17    0.090408    0.090845  ...        0.0           0.0   1980-12-17
# 4     1980-12-18    0.093029    0.093466  ...        0.0           0.0   1980-12-18
# ...          ...         ...         ...  ...        ...           ...          ...
# 10364 2022-01-20  166.979996  169.679993  ...        0.0           0.0   2022-01-20
# 10365 2022-01-21  164.419998  166.330002  ...        0.0           0.0   2022-01-21
# 10366 2022-01-24  160.020004  162.300003  ...        0.0           0.0   2022-01-24
# 10367 2022-01-25  158.979996  162.759995  ...        0.0           0.0   2022-01-25
# ...

# %%
apple_share_price_date = apple_share_price_data.iloc[:,:8]

# %%
apple_share_price_date
# Out:
#             Date        Open        High  ...     Volume  Dividends  Stock Splits
# 0     1980-12-12    0.100453    0.100890  ...  469033600        0.0           0.0
# 1     1980-12-15    0.095649    0.095649  ...  175884800        0.0           0.0
# 2     1980-12-16    0.088661    0.088661  ...  105728000        0.0           0.0
# 3     1980-12-17    0.090408    0.090845  ...   86441600        0.0           0.0
# 4     1980-12-18    0.093029    0.093466  ...   73449600        0.0           0.0
# ...          ...         ...         ...  ...        ...        ...           ...
# 10364 2022-01-20  166.979996  169.679993  ...   91420500        0.0           0.0
# 10365 2022-01-21  164.419998  166.330002  ...  122501300        0.0           0.0
# 10366 2022-01-24  160.020004  162.300003  ...  162706700        0.0           0.0
# 10367 2022-01-25  158.979996  162.759995  ...  114972000        0.0           0.0
# ...

# %%
dividends = pd.DataFrame(apple.dividends)

# %%
dividends
# Out:
#             Dividends
# Date
# 1987-05-11   0.000536
# 1987-08-10   0.000536
# 1987-11-17   0.000714
# 1988-02-12   0.000714
# 1988-05-16   0.000714
# ...               ...
# 2020-11-06   0.205000
# 2021-02-05   0.205000
# 2021-05-07   0.220000
# 2021-08-06   0.220000
# 2021-11-05   0.220000
#
# [73 rows x 1 columns]

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize=(15,7))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)



ax1.plot(apple_share_price_data.iloc[:,0], apple_share_price_data.iloc[:,1])
ax1.set_ylim(bottom=0)
ax1.set_title('Applstock price')
ax1.set_xlabel('Year')
ax1.set_ylabel('USD')

ax2.plot(apple.dividends)
ax2.set_ylim(bottom=0)
# Out:
# (0.0, 0.2309732)

# %%
apple.dividends
# Out:
# Date
# 1987-05-11    0.000536
# 1987-08-10    0.000536
# 1987-11-17    0.000714
# 1988-02-12    0.000714
# 1988-05-16    0.000714
#                 ...
# 2020-11-06    0.205000
# 2021-02-05    0.205000
# 2021-05-07    0.220000
# 2021-08-06    0.220000
# 2021-11-05    0.220000
# Name: Dividends, Length: 73, dtype: float64

# %%
amd = yf.Ticker('AMD')

# %%
amd_info = amd.info

# %%
amd_info['country']
# Out:
# 'United States'

# %%
amd_info['sector']
# Out:
# 'Technology'

# %%
amd_history = amd.history(period='max')

# %%
amd_history.iloc[0,4]
# Out:
# 219600

# %%
amd_history.head()
# Out:
#             Open      High       Low     Close  Volume  Dividends  Stock Splits
# Date
# 1980-03-17   0.0  3.302083  3.125000  3.145833  219600          0           0.0
# 1980-03-18   0.0  3.125000  2.937500  3.031250  727200          0           0.0
# 1980-03-19   0.0  3.083333  3.020833  3.041667  295200          0           0.0
# 1980-03-20   0.0  3.062500  3.010417  3.010417  159600          0           0.0
# 1980-03-21   0.0  3.020833  2.906250  2.916667  130800          0           0.0

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize=(15,7))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

ax1.plot(amd_history.iloc[:,3])
ax1.set_ylim(bottom=0)
ax1.set_title('AMD price')
ax1.set_xlabel('Year')
ax1.set_ylabel('USD')

ax2.plot(amd_history.iloc[:,4])
ax1.set_ylim(bottom=0)
ax2.set_xlabel('Year')
ax2.set_ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
amd_history.tail(10)
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 2022-01-12  138.589996  140.570007  ...          0           0.0
# 2022-01-13  139.440002  141.250000  ...          0           0.0
# 2022-01-14  131.679993  137.000000  ...          0           0.0
# 2022-01-18  134.500000  136.389999  ...          0           0.0
# 2022-01-19  133.550003  134.570007  ...          0           0.0
# 2022-01-20  126.040001  128.509995  ...          0           0.0
# 2022-01-21  120.139999  125.019997  ...          0           0.0
# 2022-01-24  115.400002  116.769997  ...          0           0.0
# 2022-01-25  114.099998  114.820000  ...          0           0.0
# 2022-01-26  114.550003  117.160004  ...          0           0.0
#
# [10 rows x 7 columns]

# %% [markdown]
# End
